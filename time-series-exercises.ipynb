# %% [markdown]
# # ACQUIRE DATA

# %% [markdown]
# ## Exercises
# Create a new local git repository and remote repository on github named time-series-exercises. Save this work for this module in your time-series-exercises repo.
#
# The end result of this exercise should be a file named acquire.py.

# %% [markdown]
# ## IMPORTS

# %%
import pandas as pd
import requests
import math

# %% [markdown]
# ### 1. Using the code from the lesson as a guide and the REST API from https://swapi.dev/ as we did in the lesson, create a dataframe named people that has all of the data for people.

# %%
# This is a URL. The end result are URI
response = requests.get('https://swapi.dev/api/')
response.json()
# Out:
# {'people': 'https://swapi.dev/api/people/',
#  'planets': 'https://swapi.dev/api/planets/',
#  'films': 'https://swapi.dev/api/films/',
#  'species': 'https://swapi.dev/api/species/',
#  'vehicles': 'https://swapi.dev/api/vehicles/',
#  'starships': 'https://swapi.dev/api/starships/'}

# %%
# Focus on just `people` page

response = requests.get('https://swapi.dev/api/people/')

# %%
data = response.json()
data
# Out:
# {'count': 82,
#  'next': 'https://swapi.dev/api/people/?page=2',
#  'previous': None,
#  'results': [{'name': 'Luke Skywalker',
#    'height': '172',
#    'mass': '77',
#    'hair_color': 'blond',
#    'skin_color': 'fair',
#    'eye_color': 'blue',
#    'birth_year': '19BBY',
#    'gender': 'male',
#    'homeworld': 'https://swapi.dev/api/planets/1/',
#    'films': ['https://swapi.dev/api/films/1/',
#     'https://swapi.dev/api/films/2/',
#     'https://swapi.dev/api/films/3/',
#     'https://swapi.dev/api/films/6/'],
#    'species': [],
#    'vehicles': ['https://swapi.dev/api/vehicles/14/',
#     'https://swapi.dev/api/vehicles/30/'],
#    'starships': ['https://swapi.dev/api/starships/12/',
#     'https://swapi.dev/api/starships/22/'],
#    'created': '2014-12-09T13:50:51.644000Z',
#    'edited': '2014-12-20T21:17:56.891000Z',
#    'url': 'https://swapi.dev/api/people/1/'},
#   {'name': 'C-3PO',
#    'height': '167',
#    'mass': '75',
#    'hair_color': 'n/a',
# ...

# %%
people_df = pd.DataFrame(data['results'])

# %%
# people_df.name.value_counts().sum()

# %%
# number_of_people = data['count']
# next_page = data['next']
# previous_page = data['previous']

# print(f'''number_of_people: {number_of_people}
# next_page: {next_page}
# previous_page: {previous_page}''')

# %%
# number_of_results = len(data['results'])
# max_page = math.ceil(number_of_people / number_of_results)

# print(f'''number_of_results: {number_of_results}
# max_page: {max_page}''')

# %%
people_df
# Out:
#                  name height mass     hair_color   skin_color  eye_color  \
# 0      Luke Skywalker    172   77          blond         fair       blue
# 1               C-3PO    167   75            n/a         gold     yellow
# 2               R2-D2     96   32            n/a  white, blue        red
# 3         Darth Vader    202  136           none        white     yellow
# 4         Leia Organa    150   49          brown        light      brown
# 5           Owen Lars    178  120    brown, grey        light       blue
# 6  Beru Whitesun lars    165   75          brown        light       blue
# 7               R5-D4     97   32            n/a   white, red        red
# 8   Biggs Darklighter    183   84          black        light      brown
# 9      Obi-Wan Kenobi    182   77  auburn, white         fair  blue-gray
#
#   birth_year  gender                          homeworld  \
# 0      19BBY    male   https://swapi.dev/api/planets/1/
# ...

# %%
# people_df = pd.DataFrame(data['results'])

# number_of_people = data['count']
# next_page = data['next']
# previous_page = data['previous']

# number_of_results = len(data['results'])
# max_page = math.ceil(number_of_people / number_of_results)

# # Perform the initial request
# response = requests.get(data['next'])
# data = response.json()

# # Add the data from the first page to the DataFrame
# people_df = people_df.append(pd.DataFrame(data['results']))

# # Continue fetching and adding data until there are no more pages
# while 'next' in data:
#     response = requests.get(data['next'])
#     data = response.json()
#     people_df = people_df.append(pd.DataFrame(data['results']))

# # Display the final DataFrame    
# print(people_df)


# # Initialize variables
# number_of_people = data['count']
# number_of_results = len(data['results'])
# max_page = math.ceil(number_of_people / number_of_results)
# next_page = data['next']
# previous_page = data['previous']

# # Create an empty DataFrame to store the data
# people_df = pd.DataFrame()

# # Perform the initial request
# response = requests.get(next_page)
# data = response.json()

# # Add the data from the first page to the DataFrame
# people_df = people_df.append(pd.DataFrame(data['results']))

# # Continue fetching and adding data until there are no more pages
# while 'next' in data:
#     response = requests.get(data['next'])
#     data = response.json()
#     people_df = people_df.append(pd.DataFrame(data['results']))

# # Display the final DataFrame    
# print(people_df)




# # Create an empty DataFrame to store the data
# people_df = pd.DataFrame()

# Perform the initial request
response = requests.get(data['next'])
data = response.json()

for i in range(10):
    response = requests.get(data['next'])
    data = response.json()
    if len(data.keys())>1:
        people_df = pd.concat([people_df, pd.DataFrame(data['results'])]).reset_index()


# # Display the final DataFrame    
people_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [10], in <cell line: 63>()
#      65     data = response.json()
#      66     if len(data.keys())>1:
# ---> 67         people_df = pd.concat([people_df, pd.DataFrame(data['results'])]).reset_index()
#      70 # # Display the final DataFrame
#      71 people_df
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
people_df

# %%
# response = requests.get(data['next'])
# number_of_people = data['count'] 
# next_page = data['next']
# name = []

# for i in range(9, 82):
#     number_of_people = data['count']
#     next_page = data['next']
#     previous_page = data['previous']
#     number_of_results = len(data['results'])
#     max_page = math.ceil(number_of_people / number_of_results)
#     result = pd.DataFrame(data['results'])
#     name.append(name)

# people_df = pd.concat(people_df, name).reset_index()


# # for i in range(9, 82):
# #     number_of_people = data['count']
# #     next_page = data['next']
# #     previous_page = data['previous']
# #     number_of_results = len(data['results'])
# #     max_page = math.ceil(number_of_people / number_of_results)
# #     # result = pd.DataFrame(data['results'])
# #     name.append(i)

# %%
people_df.name.value_counts()

# %%
people_df

# %% [markdown]
# ### 2. Do the same thing, but for planets.

# %% [markdown]
# ### 3. Extract the data for starships.

# %% [markdown]
# ### 4. Save the data in your files to local csv files so that it will be faster to access in the future.

# %% [markdown]
# ### 5. Combine the data from your three separate dataframes into one large dataframe.

# %% [markdown]
# ### 6. Acquire the Open Power Systems Data for Germany, which has been rapidly expanding its renewable energy production in recent years. The data set includes country-wide totals of electricity consumption, wind power production, and solar power production for 2006-2017. You can get the data here: https://raw.githubusercontent.com/jenfly/opsd/master/opsd_germany_daily.csv

# %% [markdown]
# ### 7. Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions in the acquire.py file and be able to re-run the functions and get the same data.
